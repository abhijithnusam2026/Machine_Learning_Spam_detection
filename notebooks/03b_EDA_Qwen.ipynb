# %% [markdown]
# # Deliverable 03b: EDA for Qwen / Large Language Models
# This notebook is dedicated to analyzing data from the perspective of an LLM summarization pipeline.
#
# Topics covered:
# 1. Sequence length distribution (tokens vs characters)
# 2. Intent class balance
# 3. Dialogue complexity estimation
